# %%
import sys
import pathlib
utils_path = pathlib.Path().absolute().parent.parent
sys.path.append(utils_path.__str__())

import utils
import plotly.io as pio
import utils.layout as lay
from utils.config import apikey
import pandas as pd
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import plotly.graph_objects as go

# %%
pio.templates.default = 'simple_white+blog_mra'

# %%
from utils.config import apikey
from eodhd import APIClient

api = APIClient(apikey)

# %%
start = "2010-01-01"
vdax = api.get_historical_data("V1X.INDX", interval="d", iso8601_start=start,
                              iso8601_end="2024-01-09")["adjusted_close"]
vdax.name = "VDAX"
vdax = vdax.astype(float)
logprice_vdax = np.log(vdax)
vdax_ret = vdax.pct_change()
logprice_vdax
# Out:
# date
# 2010-01-04    3.003700
# 2010-01-05    2.990720
# 2010-01-06    2.979095
# 2010-01-07    2.985682
# 2010-01-08    2.949688
#                 ...
# 2024-01-03    2.733068
# 2024-01-04    2.678965
# 2024-01-05    2.658860
# 2024-01-08    2.642622
# 2024-01-09    2.609334
# Name: VDAX, Length: 3559, dtype: float64

# %%
vstoxx= api.get_historical_data("V2TX.INDX", interval="d", iso8601_start=start,
                              iso8601_end="2024-01-09")["adjusted_close"]
vstoxx.name = "VDAX"
vstoxx = vstoxx.astype(float)
logprice_vstoxx = np.log(vstoxx)
vstoxx_ret = vstoxx.pct_change()
logprice_vstoxx
# Out:
# date
# 2010-01-04    3.157579
# 2010-01-05    3.141312
# 2010-01-06    3.134420
# 2010-01-07    3.122131
# 2010-01-08    3.089937
#                 ...
# 2024-01-03    2.740195
# 2024-01-04    2.660959
# 2024-01-05    2.647592
# 2024-01-08    2.639057
# 2024-01-09    2.617396
# Name: VDAX, Length: 3576, dtype: float64

# %%
df = pd.DataFrame({"VDAX":vdax,"VSTOXX":vstoxx})
df["Diff"] = df["VSTOXX"] - df["VDAX"]
fig = px.line(df)
fig.show()
# Out:
# <div>                            <div id="704fc472-d490-4283-bb4f-e24cd94c6951" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("704fc472-d490-4283-bb4f-e24cd94c6951")) {                    Plotly.newPlot(                        "704fc472-d490-4283-bb4f-e24cd94c6951",                        [{"hovertemplate":"variable=VDAX<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"VDAX","line":{"color":"#4C78A8","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"VDAX","showlegend":true,"x":["2010-01-04T00:00:00","2010-01-05T00:00:00","2010-01-06T00:00:00","2010-01-07T00:00:00","2010-01-08T00:00:00","2010-01-11T00:00:00","2010-01-12T00:00:00","2010-01-13T00:00:00","2010-01-14T00:00:00","2010-01-15T00:00:00","2010-01-18T00:00:00","2010-
# ...
